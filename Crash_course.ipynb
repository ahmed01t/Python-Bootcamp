# %%
print("hello world")
# Out:
# hello world

# %%
revenue=50
type(revenue)
# Out:
# int

# %%
expense=''' my name is ahmed tanveer i am from lahore
'''

# %%
revenue=[12,13,14,5]
for rev in revenue:
    print(f"Revenue is {rev}")
for i in range(len(revenue)):
    print(revenue[i])
# Out:
# Revenue is 12
# Revenue is 13
# Revenue is 14
# Revenue is 5
# 12
# 13
# 14
# 5

# %%
revenue=[12,13,14,5]
margins=[12,12,13,314]
for i in range(len(margins)):
    profit=margins[i]*10
    margin=profit*100/revenue[i]
    margins.append(margin)
print(margins)
# Out:
# [12, 12, 13, 314, 1000.0, 923.0769230769231, 928.5714285714286, 62800.0]
